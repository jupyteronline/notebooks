# %% [markdown]
# ## 네이버 지식인 스크랩
#
#
# ## 필요한 라이브러리 설치
# * 아나콘다 사용시 다음의 프롬프트 창을 열어 conda 명령어로 설치합니다.
# * pip 사용시 아래에 있는 명령어를 터미널로 설치합니다.
# <img src="https://i.imgur.com/Sar4gdw.jpg">
#
# ### BeautifulSoup
# * `conda install -c anaconda beautifulsoup4`
# * [Beautifulsoup4 :: Anaconda Cloud](https://anaconda.org/anaconda/beautifulsoup4)
#
# * pip 사용시 : `pip install beautifulsoup4`
#
# ### tqdm
# * `conda install -c conda-forge tqdm`
# * [tqdm/tqdm: A Fast, Extensible Progress Bar for Python and CLI](https://github.com/tqdm/tqdm)
# * `pip install tqdm`

# %%
# 라이브러리 로드
# requests는 작은 웹브라우저로 웹사이트 내용을 가져온다.
import requests
# BeautifulSoup 을 통해 읽어 온 웹페이지를 파싱한다.
from bs4 import BeautifulSoup as bs
# 크롤링 후 결과를 데이터프레임 형태로 보기 위해 불러온다.
import pandas as pd
from pandas import read_excel
from selenium import webdriver
from selenium.webdriver.common.by import By

import time
from tqdm import tqdm

def get_posts(post_urls, interval=1):

    questions = []
    answers = []
    viewnums = []
    dates = []

    for post_url in tqdm(post_urls):    

        # 크롤링 할 사이트
        try:
            res = requests.get( post_url[0], headers=headers )
            res.raise_for_status()

            time.sleep(interval) 

            post_soup = bs(res.text, 'html.parser')
            q = post_soup.find_all('h3', attrs={"class":"heading"})[0].get_text()
            post_soup.find_all('div', attrs={"class":"article_content content_lv1 _questionContentsArea"})[0]
            q_detail = post_soup.find_all('div', attrs={"class":"user_content"})[0].get_text()
            question = (q + q_detail).strip()

            date = post_soup.find('span', attrs={"class":"date"}).get_text().strip()
            viewnum = post_soup.find('em', attrs={"class":"num"}).get_text().strip()
            answer = post_soup.find('div', attrs={"class":"se-main-container"}).get_text().strip()

            questions.append(question)
            answers.append(answer)
            viewnums.append(viewnum)
            dates.append(date)
        except:
            continue

    post_df = pd.DataFrame({"question": questions, "answer": answers, "viewnum": viewnums, "date": dates})
    
    return post_df
        
        
headers = {"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/84.0.4147.135 Safari/537.36"}

# 핵심단어 읽어 오기
my_sheet = '소비키워드'
file_name = 'deskresearch.xlsx'
df = read_excel(file_name, sheet_name = my_sheet, header = 1) # index_col='번호'
keywords = df['핵심단어'].values.tolist()

for keyword in keywords:
    filename = "./urls/" + "kin-posts_" + keyword.replace(" ","") + ".csv"
    print(filename)
    
    # 파일 읽기
    df_postURLs = pd.read_csv(filename)
    post_urls = df_postURLs.values.tolist()
    try:
        # 파일 쓰기
        post_df = get_posts(post_urls, 1)
        output_filename = "./scraps/" + "kin-posts-scrapped_" + keyword.replace(" ","") + ".csv"
        print(output_filename)
        post_df.to_csv(output_filename, date_format='%Y%m%d', encoding='utf-8-sig') 
    except:
        continue
# Out:
#   0%|                                                                                                                                                                                                                                                                      | 0/1500 [00:00<?, ?it/s]
# ./urls/kin-posts_1인외식.csv
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1500/1500 [12:43<00:00,  1.96it/s]
#   0%|▎                                                                                                                                                                                                                                                             | 2/1500 [00:00<01:23, 17.99it/s]
# ./scraps/kin-posts-scrapped_1인외식.csv
# ./urls/kin-posts_가치소비.csv
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1500/1500 [21:43<00:00,  1.15it/s]
#   0%|                                                                                                                                                                                                                                                                       | 0/358 [00:00<?, ?it/s]
# ./scraps/kin-posts-scrapped_가치소비.csv
# ./urls/kin-posts_RMR.csv
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 358/358 [05:39<00:00,  1.05it/s]
#   0%|▎                                                                                                                                                                                                                                                             | 2/1420 [00:00<01:27, 16.19it/s]
# ./scraps/kin-posts-scrapped_RMR.csv
# ./urls/kin-posts_웰빙.csv
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1420/1420 [11:23<00:00,  2.08it/s]
#   0%|                                                                                                                                                                                                                                                                      | 0/1500 [00:00<?, ?it/s]
# ./scraps/kin-posts-scrapped_웰빙.csv
# ./urls/kin-posts_체험소비.csv
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1500/1500 [15:55<00:00,  1.57it/s]
#   0%|                                                                                                                                                                                                                                                                      | 0/1500 [00:00<?, ?it/s]
# ./scraps/kin-posts-scrapped_체험소비.csv
# ./urls/kin-posts_골목상권.csv
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1500/1500 [14:16<00:00,  1.75it/s]
#   0%|                                                                                                                                                                                                                                                                      | 0/1460 [00:00<?, ?it/s]
# ./scraps/kin-posts-scrapped_골목상권.csv
# ./urls/kin-posts_공유경제.csv
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1460/1460 [26:39<00:00,  1.10s/it]
#   0%|                                                                                                                                                                                                                                                                      | 0/1500 [00:00<?, ?it/s]
# ./scraps/kin-posts-scrapped_공유경제.csv
# ./urls/kin-posts_구독서비스.csv
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1500/1500 [33:43<00:00,  1.35s/it]
#   0%|                                                                                                                                                                                                                                                                      | 0/1390 [00:00<?, ?it/s]
# ./scraps/kin-posts-scrapped_구독서비스.csv
# ./urls/kin-posts_로컬푸드.csv
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1390/1390 [11:29<00:00,  2.02it/s]
#   0%|                                                                                                                                                                                                                                                                        | 0/30 [00:00<?, ?it/s]
# ./scraps/kin-posts-scrapped_로컬푸드.csv
# ./urls/kin-posts_모디슈머.csv
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 30/30 [00:36<00:00,  1.22s/it]
#   0%|                                                                                                                                                                                                                                                                      | 0/1500 [00:00<?, ?it/s]
# ./scraps/kin-posts-scrapped_모디슈머.csv
# ./urls/kin-posts_1인미디어.csv
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1500/1500 [34:37<00:00,  1.39s/it]
#   0%|                                                                                                                                                                                                                                                                      | 0/1500 [00:00<?, ?it/s]
# ./scraps/kin-posts-scrapped_1인미디어.csv
# ./urls/kin-posts_배달음식.csv
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1500/1500 [11:37<00:00,  2.15it/s]
#   0%|                                                                                                                                                                                                                                                                        | 0/78 [00:00<?, ?it/s]
# ./scraps/kin-posts-scrapped_배달음식.csv
# ./urls/kin-posts_푸드홀.csv
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 78/78 [01:42<00:00,  1.31s/it]
# 0it [00:00, ?it/s]
#   0%|                                                                                                                                                                                                                                                                       | 0/269 [00:00<?, ?it/s]
# ./scraps/kin-posts-scrapped_푸드홀.csv
# ./urls/kin-posts_스내킹스토어.csv
# ./scraps/kin-posts-scrapped_스내킹스토어.csv
# ./urls/kin-posts_스몰럭셔리.csv
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 269/269 [05:44<00:00,  1.28s/it]
#   0%|                                                                                                                                                                                                                                                                      | 0/1489 [00:00<?, ?it/s]
# ./scraps/kin-posts-scrapped_스몰럭셔리.csv
# ./urls/kin-posts_언택트.csv
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1489/1489 [20:55<00:00,  1.19it/s]
#   5%|███████████▋                                                                                                                                                                                                                                                    | 2/44 [00:00<00:02, 18.26it/s]
# ./scraps/kin-posts-scrapped_언택트.csv
# ./urls/kin-posts_에스닉푸드.csv
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 44/44 [00:02<00:00, 18.65it/s]
#   3%|███████▉                                                                                                                                                                                                                                                        | 2/65 [00:00<00:03, 19.28it/s]
# ./scraps/kin-posts-scrapped_에스닉푸드.csv
# ./urls/kin-posts_이색식재료.csv
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 65/65 [00:03<00:00, 18.75it/s]
#  18%|██████████████████████████████████████████████▌                                                                                                                                                                                                                 | 2/11 [00:00<00:00, 19.67it/s]
# ./scraps/kin-posts-scrapped_이색식재료.csv
# ./urls/kin-posts_뉴밀리어.csv
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 11/11 [00:00<00:00, 19.14it/s]
#   0%|▎                                                                                                                                                                                                                                                             | 2/1500 [00:00<01:21, 18.34it/s]
# ./scraps/kin-posts-scrapped_뉴밀리어.csv
# ./urls/kin-posts_지속가능.csv
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1500/1500 [26:07<00:00,  1.05s/it]
#   0%|▎                                                                                                                                                                                                                                                             | 2/1500 [00:00<01:18, 19.05it/s]
# ./scraps/kin-posts-scrapped_지속가능.csv
# ./urls/kin-posts_친환경.csv
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1500/1500 [14:12<00:00,  1.76it/s]
#   0%|                                                                                                                                                                                                                                                                      | 0/1500 [00:00<?, ?it/s]
# ./scraps/kin-posts-scrapped_친환경.csv
# ./urls/kin-posts_취향의세분화.csv
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1500/1500 [12:05<00:00,  2.07it/s]
#   0%|                                                                                                                                                                                                                                                                      | 0/1500 [00:00<?, ?it/s]
# ./scraps/kin-posts-scrapped_취향의세분화.csv
# ./urls/kin-posts_콘텐츠.csv
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1500/1500 [36:38<00:00,  1.47s/it]
#   0%|                                                                                                                                                                                                                                                                      | 0/1500 [00:00<?, ?it/s]
# ./scraps/kin-posts-scrapped_콘텐츠.csv
# ./urls/kin-posts_콜라보레이션.csv
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1500/1500 [26:16<00:00,  1.05s/it]
#   0%|                                                                                                                                                                                                                                                                         | 0/4 [00:00<?, ?it/s]
# ./scraps/kin-posts-scrapped_콜라보레이션.csv
# ./urls/kin-posts_탈도심화.csv
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00,  7.06it/s]
#   0%|▏                                                                                                                                                                                                                                                             | 1/1500 [00:00<02:44,  9.11it/s]
# ./scraps/kin-posts-scrapped_탈도심화.csv
# ./urls/kin-posts_특수부위.csv
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1500/1500 [26:27<00:00,  1.06s/it]
#   0%|▎                                                                                                                                                                                                                                                             | 2/1420 [00:00<01:12, 19.66it/s]
# ./scraps/kin-posts-scrapped_특수부위.csv
# ./urls/kin-posts_펫.csv
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1420/1420 [10:08<00:00,  2.33it/s]
#   0%|                                                                                                                                                                                                                                                                       | 0/607 [00:00<?, ?it/s]
# ./scraps/kin-posts-scrapped_펫.csv
# ./urls/kin-posts_푸드테크.csv
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 607/607 [14:01<00:00,  1.39s/it]
#   0%|                                                                                                                                                                                                                                                                      | 0/1500 [00:00<?, ?it/s]
# ./scraps/kin-posts-scrapped_푸드테크.csv
# ./urls/kin-posts_K-푸드.csv
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1500/1500 [10:00<00:00,  2.50it/s]
#   0%|                                                                                                                                                                                                                                                                         | 0/4 [00:00<?, ?it/s]
# ./scraps/kin-posts-scrapped_K-푸드.csv
# ./urls/kin-posts_홈코노미.csv
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 4/4 [00:05<00:00,  1.43s/it]
#   0%|                                                                                                                                                                                                                                                                       | 0/168 [00:00<?, ?it/s]
# ./scraps/kin-posts-scrapped_홈코노미.csv
# ./urls/kin-posts_MZ세대.csv
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 168/168 [04:11<00:00,  1.50s/it]
#   0%|                                                                                                                                                                                                                                                                        | 0/47 [00:00<?, ?it/s]
# ./scraps/kin-posts-scrapped_MZ세대.csv
# ./urls/kin-posts_럭셔리미식.csv
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 47/47 [00:59<00:00,  1.27s/it]
#   0%|                                                                                                                                                                                                                                                                      | 0/1500 [00:00<?, ?it/s]
# ./scraps/kin-posts-scrapped_럭셔리미식.csv
# ./urls/kin-posts_듀얼매장.csv
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1500/1500 [33:24<00:00,  1.34s/it]
#   0%|                                                                                                                                                                                                                                                                      | 0/1500 [00:00<?, ?it/s]
# ./scraps/kin-posts-scrapped_듀얼매장.csv
# ./urls/kin-posts_무알콜.csv
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1500/1500 [24:00<00:00,  1.04it/s]
#   0%|                                                                                                                                                                                                                                                                      | 0/1500 [00:00<?, ?it/s]
# ./scraps/kin-posts-scrapped_무알콜.csv
# ./urls/kin-posts_안심식당.csv
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1500/1500 [23:57<00:00,  1.04it/s]
# ./scraps/kin-posts-scrapped_안심식당.csv
